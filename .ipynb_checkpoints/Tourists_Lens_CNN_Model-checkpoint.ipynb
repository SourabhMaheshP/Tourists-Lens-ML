# %%
# !nvidia-smi
# Out:
# Wed Sep 16 08:29:01 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # GPU Config - Tensorflow

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.9
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# # Inception-V3 Pretrained Model / Transfer Learning

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %%
IMAGE_SIZE = [224, 224]

train_path = 'drive/My Drive/Monument_Datasets/train'
test_path = 'drive/My Drive/Monument_Datasets/test'

# %%
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# ...
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
for layer in inception.layers:
    layer.trainable = False

# %%
# Number Of Classes 
folders = glob('drive/My Drive/Monument_Datasets/train/*')
folders
# Out:
# ['drive/My Drive/Monument_Datasets/train/India Gate',
#  'drive/My Drive/Monument_Datasets/train/Lotus Temple',
#  'drive/My Drive/Monument_Datasets/train/Qutb Shahi Tombs',
#  'drive/My Drive/Monument_Datasets/train/Agra Fort',
#  'drive/My Drive/Monument_Datasets/train/Basilica Of Bom Jesus',
#  'drive/My Drive/Monument_Datasets/train/Taj Mahal',
#  'drive/My Drive/Monument_Datasets/train/Qutub Minar',
#  'drive/My Drive/Monument_Datasets/train/Golden Temple',
#  'drive/My Drive/Monument_Datasets/train/Hawa Mahal']

# %%
x = Flatten()(inception.output)

# %%
output_layer = Dense(len(folders), activation='softmax')(x)

# Create model
model = Model(inputs=inception.input, outputs=output_layer)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 111, 111, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   rotation_range = 20,
                                   width_shift_range=[-10,10],
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (224, 224),
                                            batch_size = 16,
                                            class_mode = 'categorical')
# Out:
# Found 1251 images belonging to 9 classes.
# Found 303 images belonging to 9 classes.

# %%
# Model Training
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=5,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# WARNING:tensorflow:From <ipython-input-12-5ca5baa6e8fb>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/5
# 79/79 [==============================] - 707s 9s/step - loss: 2.9526 - accuracy: 0.8122 - val_loss: 0.7216 - val_accuracy: 0.9340
# Epoch 2/5
# 79/79 [==============================] - 32s 400ms/step - loss: 0.6137 - accuracy: 0.9376 - val_loss: 0.8373 - val_accuracy: 0.9208
# Epoch 3/5
# 79/79 [==============================] - 32s 403ms/step - loss: 0.7363 - accuracy: 0.9392 - val_loss: 1.2861 - val_accuracy: 0.9076
# Epoch 4/5
# 79/79 [==============================] - 32s 401ms/step - loss: 0.4547 - accuracy: 0.9632 - val_loss: 2.6592 - val_accuracy: 0.8647
# Epoch 5/5
# 79/79 [==============================] - 32s 404ms/step - loss: 0.5941 - accuracy: 0.9464 - val_loss: 1.2579 - val_accuracy: 0.9208

# %%
from tensorflow.keras.models import load_model

model.save('drive/My Drive/Monument_Datasets/trained_model.h5')

# %%
import matplotlib.pyplot as plt

# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
y_pred = model.predict(test_set)

y_pred
# Out:
# array([[7.5305069e-31, 1.3926151e-32, 4.6227784e-27, ..., 4.8578832e-11,
#         4.9153050e-30, 3.5588462e-29],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 9.9451662e-34,
#         3.2495800e-34, 1.0000000e+00],
#        [1.0818271e-30, 1.0000000e+00, 1.6023698e-33, ..., 1.4466315e-34,
#         7.4812184e-34, 6.7877146e-32],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         7.7852768e-38, 3.3828978e-34],
#        [4.2060549e-07, 8.8132550e-24, 1.6739282e-10, ..., 2.2185806e-21,
#         9.5938262e-29, 7.1104132e-27],
#        [2.6789735e-26, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 6.6843048e-28]], dtype=float32)

# %%
import numpy as np
y_pred = np.argmax(y_pred, axis=1)

# %%
y_pred
# Out:
# array([5, 8, 1, 2, 5, 4, 8, 8, 2, 2, 5, 2, 4, 6, 6, 2, 1, 3, 0, 2, 6, 4,
#        8, 8, 4, 8, 4, 6, 4, 7, 8, 0, 1, 7, 1, 2, 7, 5, 8, 5, 5, 2, 4, 0,
#        8, 5, 8, 1, 8, 1, 0, 0, 4, 7, 4, 5, 8, 1, 1, 0, 7, 0, 0, 6, 4, 8,
#        8, 3, 3, 5, 7, 4, 7, 0, 2, 6, 6, 8, 1, 6, 5, 0, 0, 1, 4, 8, 8, 8,
#        7, 2, 4, 2, 4, 2, 7, 6, 0, 0, 0, 6, 2, 7, 2, 0, 4, 0, 2, 7, 8, 2,
#        0, 2, 6, 6, 6, 7, 7, 5, 0, 1, 0, 2, 7, 7, 6, 4, 2, 4, 6, 8, 2, 7,
#        0, 8, 7, 4, 1, 2, 4, 2, 0, 2, 6, 8, 2, 2, 2, 0, 6, 7, 8, 5, 3, 7,
#        7, 1, 4, 8, 0, 1, 0, 3, 6, 3, 6, 3, 5, 1, 6, 5, 4, 4, 0, 8, 1, 4,
#        3, 4, 5, 4, 3, 2, 7, 6, 5, 2, 3, 4, 3, 7, 3, 2, 4, 5, 4, 3, 6, 6,
#        7, 2, 2, 8, 5, 7, 4, 6, 2, 2, 1, 0, 7, 5, 5, 1, 5, 1, 1, 3, 8, 5,
#        3, 7, 0, 2, 5, 1, 8, 7, 2, 3, 5, 3, 0, 3, 7, 1, 6, 0, 2, 4, 8, 6,
#        7, 5, 6, 1, 3, 6, 2, 6, 3, 1, 1, 0, 0, 8, 5, 8, 8, 8, 3, 8, 1, 5,
#        0, 1, 5, 6, 7, 4, 5, 2, 7, 5, 6, 0, 4, 1, 0, 8, 0, 0, 1, 5, 0, 2,
# ...
